# %% [markdown]
# Step 1: Import the needed libraries

# %%
import numpy as np
import pandas as pd
pd.options.mode.chained_assignment = None
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # Step 2: Loading data
# I have used the dataset that has Football players in Fifa 19 and their various attributes. Dataset available on [this link](https://www.kaggle.com/karangadiya/fifa19)

# %%
df = pd.read_csv("data.csv") #Loading file
df.shape #Number of rows and columns
# Out:
# (18207, 89)

# %%
df.head() #First 5 rows
# Out:
#    Unnamed: 0      ID  ... GKReflexes  Release Clause
# 0           0  158023  ...        8.0         €226.5M
# 1           1   20801  ...       11.0         €127.1M
# 2           2  190871  ...       11.0         €228.1M
# 3           3  193080  ...       94.0         €138.6M
# 4           4  192985  ...       13.0         €196.4M
#
# [5 rows x 89 columns]

# %%
df.head(10) #First 10 rows
# Out:
#    Unnamed: 0      ID  ... GKReflexes  Release Clause
# 0           0  158023  ...        8.0         €226.5M
# 1           1   20801  ...       11.0         €127.1M
# 2           2  190871  ...       11.0         €228.1M
# 3           3  193080  ...       94.0         €138.6M
# 4           4  192985  ...       13.0         €196.4M
# 5           5  183277  ...        8.0         €172.1M
# 6           6  177003  ...        9.0         €137.4M
# 7           7  176580  ...       37.0           €164M
# 8           8  155862  ...       11.0         €104.6M
# 9           9  200389  ...       89.0         €144.5M
#
# [10 rows x 89 columns]

# %%
df.tail() #Last 5 rows
# Out:
#        Unnamed: 0      ID  ... GKReflexes  Release Clause
# 18202       18202  238813  ...        9.0           €143K
# 18203       18203  243165  ...       12.0           €113K
# 18204       18204  241638  ...       13.0           €165K
# 18205       18205  246268  ...        9.0           €143K
# 18206       18206  246269  ...        9.0           €165K
#
# [5 rows x 89 columns]

# %%
df.index #Show indexing of observations
# Out:
# RangeIndex(start=0, stop=18207, step=1)

# %%
df.columns #List all the columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
df.columns[72] #Name of 73rd column
# Out:
# 'Strength'

# %%
df.Name # Print all the values in column "Name"
# Out:
# 0                  L. Messi
# 1         Cristiano Ronaldo
# 2                 Neymar Jr
# 3                    De Gea
# 4              K. De Bruyne
#                 ...
# 18202          J. Lundstram
# 18203    N. Christoffersson
# 18204             B. Worman
# 18205        D. Walker-Rice
# 18206             G. Nugent
# Name: Name, Length: 18207, dtype: object

# %%
df[['Name' , 'Age']] # Print all the values in columns "Name" and "Age"
# Out:
#                      Name  Age
# 0                L. Messi   31
# 1       Cristiano Ronaldo   33
# 2               Neymar Jr   26
# 3                  De Gea   27
# 4            K. De Bruyne   27
# ...                   ...  ...
# 18202        J. Lundstram   19
# 18203  N. Christoffersson   19
# 18204           B. Worman   16
# 18205      D. Walker-Rice   17
# 18206           G. Nugent   16
#
# [18207 rows x 2 columns]

# %%
df.Name.nunique()# Print no. of unique values in column "Name"
# Out:
# 17194

# %%
df.dtypes #List data types of all columns
# Out:
# Unnamed: 0          int64
# ID                  int64
# Name               object
# Age                 int64
# Photo              object
#                    ...
# GKHandling        float64
# GKKicking         float64
# GKPositioning     float64
# GKReflexes        float64
# Release Clause     object
# Length: 89, dtype: object

# %%
df.describe #Give a description of dataset
# Out:
# <bound method NDFrame.describe of        Unnamed: 0      ID  ... GKReflexes  Release Clause
# 0               0  158023  ...        8.0         €226.5M
# 1               1   20801  ...       11.0         €127.1M
# 2               2  190871  ...       11.0         €228.1M
# 3               3  193080  ...       94.0         €138.6M
# 4               4  192985  ...       13.0         €196.4M
# ...           ...     ...  ...        ...             ...
# 18202       18202  238813  ...        9.0           €143K
# 18203       18203  243165  ...       12.0           €113K
# 18204       18204  241638  ...       13.0           €165K
# 18205       18205  246268  ...        9.0           €143K
# 18206       18206  246269  ...        9.0           €165K
#
# [18207 rows x 89 columns]>

# %%
df.describe(include = 'all') #Give a description of dataset with all columns
# Out:
#           Unnamed: 0             ID  ...    GKReflexes  Release Clause
# count   18207.000000   18207.000000  ...  18159.000000           16643
# unique           NaN            NaN  ...           NaN            1244
# top              NaN            NaN  ...           NaN           €1.1M
# freq             NaN            NaN  ...           NaN             557
# mean     9103.000000  214298.338606  ...     16.710887             NaN
# std      5256.052511   29965.244204  ...     17.955119             NaN
# min         0.000000      16.000000  ...      1.000000             NaN
# 25%      4551.500000  200315.500000  ...      8.000000             NaN
# 50%      9103.000000  221759.000000  ...     11.000000             NaN
# 75%     13654.500000  236529.500000  ...     14.000000             NaN
# max     18206.000000  246620.000000  ...     94.000000             NaN
#
# [11 rows x 89 columns]

# %%
df.loc[[0,1,2],["Name","Age","Overall"]] # Select "Name", "Age" and overall from 0th, 1st and 2nd row
# Out:
#                 Name  Age  Overall
# 0           L. Messi   31       94
# 1  Cristiano Ronaldo   33       94
# 2          Neymar Jr   26       92

# %%
df.iloc[3:6, [2,3,5]] #Select 3rd, 4th and 6th column from 4th till 6th row
# Out:
#            Name  Age Nationality
# 3        De Gea   27       Spain
# 4  K. De Bruyne   27     Belgium
# 5     E. Hazard   27     Belgium

# %%
total_cells = np.product(df.shape) #Total no. of cells in dataset
total_cells
# Out:
# 1620423

# %%
missing_values_count = df.isnull().sum() #Number of missing values per column
missing_values_count[0:10] #Number of missing values for first 10 columns
# Out:
# Unnamed: 0       0
# ID               0
# Name             0
# Age              0
# Photo            0
# Nationality      0
# Flag             0
# Overall          0
# Potential        0
# Club           241
# dtype: int64

# %%
missing_values_count[10:20] #Number of missing values for 11th to 20th columns
# Out:
# Club Logo                    0
# Value                        0
# Wage                         0
# Special                      0
# Preferred Foot              48
# International Reputation    48
# Weak Foot                   48
# Skill Moves                 48
# Work Rate                   48
# Body Type                   48
# dtype: int64

# %%
missing_values_count[20:30] #Number of missing values for 21st to 30th columns
# Out:
# Real Face                  48
# Position                   60
# Jersey Number              60
# Joined                   1553
# Loaned From             16943
# Contract Valid Until      289
# Height                     48
# Weight                     48
# LS                       2085
# ST                       2085
# dtype: int64

# %%
total_missing_values_count = missing_values_count.sum() #Total number of cells with missing values
total_missing_values_count
# Out:
# 76984

# %%
df.Age.mean() #Average of "Age" column
# Out:
# 25.122205745043114

# %%
df.dropna(subset = ["Club", "Position", "Joined", "Contract Valid Until"], inplace = True) #drop all the rows where "Club", "Position", "Joined", "Contract Valid Until" is null directly from data
df.shape
# Out:
# (16654, 89)

# %%
df["Loaned From"].fillna("None", inplace = True) #Replace Null values in "Loaned From" column with "None"
df["Release Clause"].fillna("€0", inplace = True) #Replace Null values in "Release Claus" column with "€0"
missing_values_count = df.isnull().sum()
missing_values_count[["Loaned From", "Release Clause"]]
# Out:
# Loaned From       0
# Release Clause    0
# dtype: int64

# %%
GKdf = df[df["Position"] == "GK"] #Create a new dataset where "Position" = "GK"
GKdf.shape
# Out:
# (1903, 89)

# %%
GKdf.head()
# Out:
#     Unnamed: 0      ID  ... GKReflexes  Release Clause
# 3            3  193080  ...       94.0         €138.6M
# 9            9  200389  ...       89.0         €144.5M
# 18          18  192448  ...       90.0         €123.3M
# 19          19  192119  ...       88.0         €113.7M
# 22          22  167495  ...       87.0          €62.7M
#
# [5 rows x 89 columns]

# %%
GKdf.drop(["LS","ST","RS"], axis = 1) #Show the dataset without "LS", "ST", "RS" column
# Out:
#        Unnamed: 0      ID  ... GKReflexes  Release Clause
# 3               3  193080  ...       94.0         €138.6M
# 9               9  200389  ...       89.0         €144.5M
# 18             18  192448  ...       90.0         €123.3M
# 19             19  192119  ...       88.0         €113.7M
# 22             22  167495  ...       87.0          €62.7M
# ...           ...     ...  ...        ...             ...
# 18178       18178  243158  ...       51.0            €94K
# 18180       18180  221669  ...       45.0            €78K
# 18183       18183   53748  ...       46.0              €0
# 18194       18194  245862  ...       44.0           €109K
# 18198       18198  242844  ...       48.0           €165K
#
# [1903 rows x 86 columns]

# %%
del GKdf["LS"] #Remove "LS" column from dataset
GKdf.shape
# Out:
# (1903, 88)

# %%
Gkdf = GKdf.drop(['ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
       'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
       'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB'], axis = 1, inplace = True) #Remove the list of columns from dataset
GKdf.shape
# Out:
# (1903, 63)

# %%
GK_missing_values_count = GKdf.isnull().sum()
GK_missing_values_count.sum()
# Out:
# 0

# %%
plt.figure(figsize=(20,6))
plt.title("Age Distribution")
sns.lineplot(data=GKdf["Age"], label="Age of players")
plt.xlabel("Player Index")
# Out:
# Text(0.5, 0, 'Player Index')

# %%
plt.figure(figsize=(20,10))
plt.title("Age by nationality")
sns.barplot(x = GKdf['Nationality'], y = GKdf['Age'])

# Add label for vertical axis
plt.ylabel("Age in years")
# Out:
# Text(0, 0.5, 'Age in years')
